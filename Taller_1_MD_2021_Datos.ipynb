# %% [markdown]
# <a href="https://colab.research.google.com/github/jcarvajalri/MineriaDatosUN/blob/main/Taller_1_MD_2021_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Universidad Nacional de Colombia
# ##Minería de Datos
#
# ## Prof. Elizabeth León
# ## **Ejercicio Tipos de datos**
#
#
# ##Presentado por: John David Carvajal
#
#
# ---

# %% [markdown]
# **Carga de archivos**
#
# 1. Bajar el archivo Iris del repositorio UCI de Machine Learning UCI(1936):  https://archive.ics.uci.edu/ml/index.php
#
# 2. Cambiarle el nombre por iris.csv
# 3. Editarlo y colocar en la primera fila:
# sepalo_largo,sepalo_ancho,petalo_largo,petal_ancho,clase

# %%
import pandas as pd
import io

# %%
import seaborn as sns
df = sns.load_dataset('iris')
df.head()
df.shape
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Para visualizar el contenido del archivo:

# %% [markdown]
# **Responder**
#
# ¿Qué tipo de datos contiene este conjunto de datos?
#
# *R//:* Contiene la caracteristicas de tipos de especie de flores (setosa, versicolor, virginica) como , largo y ancho del cepalo  y del petalo.
#
#
# ¿Que características tienen cada una de sus dimensiones?
#
# *R//:* A continuación se presenta las caracteristicas de cada una de las dimensiones:
#
#
#
# *   sepal length: Atributo numerico en cm. Dato continuo
# *   sepal width: Atributo numérico en cm. Dato continuo
# *   petal length: Atributo numérico en cm. Dato continuo
# *   petal width: Atributo numérico en cm, Dato continuo
# *   species: Atributo string o varchar , contiene la descripción de la clase de flor: setosa, versicolor, virginica.
#
#
#
# ¿Qué tarea de minería podría realizarse con este conjunto?
#
# *R//:* Con este conjunto de datos se podria realizar una correlación entre las variables, analizar la variabilidad de los atributos númericos , una clasificación y comparación entre los componenest.
#
# ¿Qué puede decir de la calidad del conjunto de datos?
#
# *R//:* La calidad de los datos es buena , sin embargo considero que es muy escaza. Adicionalmente se podría tener otros atributos para cada registro como color. No se identifica que algún atributo este fuera del rango frente a los otros. Tampoco se identifica datos repetidos.

# %% [markdown]
# **2. Cargar el archivo canasto.csv**

# %%
uploaded = files.upload()
df2 = pd.read_csv(io.BytesIO(uploaded['canasto.txt']), sep=';')
df2.shape
df2
# Out:
#      <input type="file" id="files-17dbd326-80ce-4a3d-a1be-43b420233ef6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17dbd326-80ce-4a3d-a1be-43b420233ef6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving canasto.txt to canasto.txt
#    ID  Leche  Cerveza  Panales    Pan  Mantequilla  Galletas
# 0   1   True     True     True  False        False     False
# 1   2   True    False    False   True         True     False
# 2   3   True    False     True  False        False      True
# 3   4  False    False    False   True         True      True
# 4   5  False     True     True  False        False      True
# 5   6   True    False     True   True         True     False
# 6   7  False    False     True   True         True     False
# ...

# %% [markdown]
# **Responder**
#
# ¿Qué tipo de datos contiene este conjunto de datos?
#
# *R//:* El set de datos contieene la relación de articulos que compra una persona cuando hace mercado. Esta relación hace referencia a los articulos que compro un cliente (cada registro) en una compra.Por ejemplo en la fila 1, el cliente llevo leche, cerveza y pañales.
#
# ¿Que características tienen cada una de sus dimensiones?
#
# *R//:* A continuación se presenta las caracteristicas de cada uno de los atributos
#
# *   Leche: Atributo Booleano (True o False)
# *   Cerveza: Atributo Booleano (True o False)
# *   Pañales: Atributo Booleano (True o False)
# *   Pan: Atributo Booleano (True o False)
# *   Mantequilla: Atributo Booleano (True o False)
# *   Galletas: Atributo Booleano (True o False)
#
# Cada registro hace referencia a la compra que realizó un cliente y los articulos que llevo.
#
# ¿Qué tarea de minería podría realizarse con este conjunto?
#
# *R//:* Con este conjunto de datos se podria realizar una correlación entre las variables, es decir que articulos estan relacionados en una misma compra. Tambien se puede determinar cual es el articulo que mas se vende, o tiene por lo general una dependencia de otro.
#
# ¿Qué puede decir de la calidad del conjunto de datos?
#
# *R//:* La calidad de los datos es buena, todos los atributos mantienen el mismo estandar de los booleanos, sin embargo considero que es muy escaza para realizar un análisis mas profunco. Adicionalmente se podría tener otros atributos para cada registro como como la hora en que se realiza la compra de los articulos , y la cantidad de cada articulo.

# %% [markdown]
# **3. Ejercicio**
# Obtenga el conjunto Adult del repositorio UCI Machine Learning Repository (https://archive.ics.uci.edu/ml/index.php). Este conjunto de datos corresponde a datos del censo de USA de 1994
#
# 1. Cárguelo
#
# *R//* El set de datos que se selecciono fueron accidentes de carros. A continuación se encuentra la carga de datos.

# %%
uploaded = files.upload()
df3 = pd.read_csv(io.BytesIO(uploaded['car_crashes.csv']), sep=',')
df3.shape
df3
# Out:
#      <input type="file" id="files-bd9ff609-76ec-4425-bc7a-5748a6f2cb25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd9ff609-76ec-4425-bc7a-5748a6f2cb25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car_crashes.csv to car_crashes.csv
#     total  speeding  alcohol  ...  ins_premium  ins_losses  abbrev
# 0    18.8     7.332    5.640  ...       784.55      145.08      AL
# 1    18.1     7.421    4.525  ...      1053.48      133.93      AK
# 2    18.6     6.510    5.208  ...       899.47      110.35      AZ
# 3    22.4     4.032    5.824  ...       827.34      142.39      AR
# 4    12.0     4.200    3.360  ...       878.41      165.63      CA
# 5    13.6     5.032    3.808  ...       835.50      139.91      CO
# ...

# %% [markdown]
# 2. Describa el conjunto de datos: Número de instancias,Número de atributos. ¿Qué tareas de la minería de datos se pueden aplicar? Explique.
#
# *R//:* El conjunto de datos seleccionado hace referencia a accidentes de carros. Cada variable atributo hace refrencia a al accediente. aidcionalmente hay un atributo que habla del total de accidentes que tienen tuvieron las mismas caracteristicas dentro de una ciudad..  Adicionalmente se encuentra una relación con con los respectivos seguros de los carros.
#
# Se puede reralizar una tarea de mineria de correlaccion de datos entre los siniestros de diferentes ciudades , teniendo en cuenta atributos como el grado de alcohol del conductos. Tambien se puede realizar un trabajo de clasifiación.
#
# 3. ¿El conjunto de datos está etiquetado? ¿Cuántas clases tiene el conjunto de datos?
#
# *R//:* Lo datos se encuentran etiqeutados, a continuación se encuentran los atributos que tiene el set de datos:
#
#
# *   Total : Atributo númerico. Describe la cantidad de accidentes con los atributos posteriores.
# *   Speeding: Atributo numérico, velocidad del vehiculo cuando tuvo el accidente.
# *   Alcohol: Atributo numnérico. Grado del alcohol del conductor.
# *   No_Distracted. Atributo numérico . Indicador de distracción del conductor.
# *  No_Previus: Atributo numerico.
# *   Ins_Premiums: Atributo Numérico. Seguro premium del vehículo.
# *  Ins_Losses: Perdida del seguro.
# *  Abbrev. Atributo describtivo, Indicador de la ciudad donde se presentaron los siniestros.
#
#
#
#
# 4. ¿Cuántos atributos son numéricos y cuántos categóricos? De los atributos numéricos ¿Cuántos son continuos y cuántos discretos?
#
# *R//* 7 Atributos son numericos , y 1 atributo es categorico.Los 7 atributos numericos son continuos. El tributo categorico se podría definir como discreto ya que hace refrencia a una ciudad, la cual la podríamos determinar con un cod.
#
# 5. ¿Existen atributos binarios, ordinales, intervalo o de radio? ¿cuáles?
#
# *R//* El set de datos no presneta atributos binarios , cada uno de los datos numericos se encuentran dentro de un intervalo , y no se evidencian datos fuera de rando. El dato que hace ref a abre es descriptivo y representa la ciudad donde paso el siniestro.
